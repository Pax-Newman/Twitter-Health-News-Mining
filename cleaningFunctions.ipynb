# %%
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize as tokenize
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
stemIgnStop = SnowballStemmer('english', ignore_stopwords=True)
lemmer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

from sklearn.feature_extraction.text import TfidfVectorizer
tfidfVec = TfidfVectorizer()
# Out:
# [nltk_data] Downloading package wordnet to /home/mayla/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/mayla/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /home/mayla/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/mayla/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
datafile = "data/dataset.csv"
twitter = pd.read_csv(datafile)

# %%
#removes usernames, links, and converts to lowercase
def remUserLinkCase(tweets, remHash = False):
    if remHash==True:
        return tweets.str.replace(r'http\S+','',regex=True).str.replace(r'@\S+','',regex=True).str.replace(r'#\S+','',regex=True).str.lower()
    else:
        return tweets.str.replace(r'http\S+','',regex=True).str.replace(r'@\S+','',regex=True).str.lower()

#removes punctuation
def remPunct(tweets, remNum = False):
    if remNum==True:
        return tweets.str.replace(r'[\d]','', regex=True).str.replace(r'[^\w\s]','', regex=True)
    else:
        return tweets.str.replace(r'[^\w\s]','', regex=True)

#removes stop words
def remStopWords(tweets):
    for i in range(0,len(tweets)):
        tweets[i] = ' '.join([w for w in tokenize(tweets[i]) if not w in stop_words])
    return tweets

#lemmatizes words; optional to remove or leave stop words
def lem(tweets, remStop = True):
    if remStop == True:
        for i in range(0,len(tweets)):
            tweets[i] = ' '.join([lemmer.lemmatize(w) for w in tokenize(tweets[i]) if not w in stop_words])
        return tweets
    else:
        for i in range(0,len(tweets)):
            tweets[i] = ' '.join([lemmer.lemmatize(w) for w in tokenize(tweets[i])])
        return tweets
    
#stems words; optional to remove or leave stop words
def stem(tweets, remStop = True):
    if remStop == True:
        for i in range(0,len(tweets)):
            tweets[i] = ' '.join([stemmer.stem(w) for w in tokenize(tweets[i]) if not w in stop_words])
        return tweets
    else:
        for i in range(0,len(tweets)):
            tweets[i] = ' '.join([stemmer.stem(w) for w in tokenize(tweets[i])])
        return tweets

# %%
lemmed = lem(remPunct(remUserLinkCase(twitter["content"])), remStop = True)

# %%
stemmed = stem(remPunct(remUserLinkCase(twitter["content"])), remStop = True)

# %%
noTagLem = lem(remPunct(remUserLinkCase(twitter["content"], remHash = True), remNum = True), remStop = True)

# %%
noTagVec = tfidfVec.fit_transform(noTagLem.tolist())

# %%
for i in range(len(lemmed)):
    if "äúawesome" in lemmed[i]:
        print(lemmed[i])
# Out:
# science vaccine safety äúawesome challenge trying prove negativeäù nonopinion

# %%
tfidfVec.get_feature_names_out()[24783:25783]
# Out:
# array(['webcast', 'webchat', 'webenabled', 'webinar', 'webmd', 'webola',
#        'webolalike', 'website', 'webster', 'websurfing', 'webthanks',
#        'wed', 'wedding', 'weddingcrashing', 'weddingsfunerals', 'wedge',
#        'wednesday', 'wee', 'weed', 'weeding', 'weeek', 'week',
#        'weekchilds', 'weekday', 'weeke', 'weekend', 'weekly', 'weeknight',
#        'weekold', 'weekäîor', 'weep', 'wei', 'weider', 'weigh', 'weighed',
#        'weighing', 'weighins', 'weighs', 'weight', 'weightasthma',
#        'weightcontrol', 'weighthealth', 'weightit', 'weightlifter',
#        'weightlifting', 'weightloss', 'weightloss_health',
#        'weightlosssurgery', 'weightmachine', 'weightrelated',
#        'weightthanks', 'weightthe', 'weighttraining', 'weightvia',
#        'weighty', 'weightä', 'weightäîand', 'weightäîsometimes',
#        'weightäô', 'weighä', 'weigä', 'weil', 'weiner', 'weinman', 'weir',
#        'weird', 'weirder', 'weirdest', 'weirdly', 'wel', 'welch',
#        'welcome', 'welcomed', 'welcoming', 'welfare', 'well',
#        'welladjusted', 'wellbalanced', 'wellbeing', 'wellbutrin',
#        'wellcome', 'wellesley', 'wellestablished', 'wellfunded',
#        'wellinformed', 'wellington', 'welll', 'welllaid', 'wellnamed',
#        'wellness', 'wellnesswhat', 'wellnessä', 'welloff', 'wellpoint',
#        'wellread', 'wellrested', 'wellstocked', 'wellstudied',
#        'welltimed', 'wellwoman', 'welläù', 'welsh', 'welä', 'wemotional',
#        'wendell', 'wendy', 'went', 'wept', 'wer', 'werent', 'werenäôt',
#        'werewolf', 'wesleyan', 'wessels', 'west', 'western',
#        'westerndeveloped', 'westernfitness', 'westin', 'westminster',
#        'westwood', 'wet', 'weve', 'wexercise', 'wezel', 'weä', 'weäôll',
#        'weäôre', 'weäôve', 'wfab', 'wfew', 'wfield', 'wforce', 'wfp',
#        'wfresh', 'wgaining', 'wgestational', 'wh', 'whack', 'whale',
#        'whalesand', 'wham', 'whammy', 'whatever', 'whateverä', 'whathow',
#        'whatll', 'whats', 'whatsoever', 'whatsup', 'whatt', 'whatäôs',
#        'wheadlines', 'whealthier', 'whealthy', 'wheart', 'wheat',
#        'wheatbased', 'wheatberry', 'wheel', 'wheelchair',
#        'wheelchairbound', 'wheeled', 'wheeze', 'wheezing', 'wheezy',
#        'whelan', 'whenhow', 'wherbs', 'wherbsgarlic', 'whereabouts',
#        'whereas', 'whered', 'wheres', 'wherever', 'whet', 'whether',
#        'whew', 'whey', 'whichever', 'whig', 'whigher', 'whiledancing',
#        'whilst', 'whimsical', 'whip', 'whiplash', 'whipped', 'whipping',
#        'whirl', 'whiskey', 'whisper', 'whisperer', 'whistle',
#        'whistleblower', 'whistleblowing', 'whitaker', 'white',
#        'whitecoat', 'whitehall', 'whitehalldriven', 'whitehorse',
#        'whiten', 'whitener', 'whitening', 'whitenoise', 'whiter',
#        'whitman', 'whitney', 'whittle', 'whiz', 'whizz', 'who', 'whoa',
#        'whod', 'whodathunkit', 'whoever', 'whole', 'wholebody',
#        'wholediet', 'wholefamily', 'wholefood', 'wholegene', 'wholegrain',
#        'wholeperson', 'wholesale', 'wholesome', 'wholewheat', 'wholeä',
#        'wholl', 'wholly', 'whoonga', 'whoop', 'whoopi', 'whoopie',
#        'whooping', 'whopper', 'whopping', 'whose', 'whove', 'whoyouknow',
#        'whoäôs', 'whoäôve', 'whs', 'wht', 'why', 'whä', 'wi', 'wick',
#        'wicked', 'wide', 'widely', 'widen', 'widened', 'widening',
#        'widens', 'wider', 'widespread', 'widow', 'widowed', 'widower',
#        'wiener', 'wife', 'wifi', 'wig', 'wigged', 'wiggle', 'wigglys',
#        'wii', 'wiki', 'wikipedia', 'wikipedias', 'wil', 'wild', 'wilde',
#        'wilderness', 'wildest', 'wildfire', 'wildlife', 'wildly',
#        'wilkinson', 'wilko', 'willens', 'willett', 'william', 'williams',
#        'willing', 'willingness', 'willl', 'willpower', 'willy', 'willya',
#        'wilson', 'wimpier', 'wimpy', 'win', 'wind', 'winder', 'windfall',
#        'winding', 'windless', 'window', 'windowshop', 'windpipe',
#        'windsor', 'windsoressex', 'windy', 'wine', 'wineglazed',
#        'winehouse', 'winehouses', 'wineor', 'winery', 'wing', 'winged',
#        'wink', 'winner', 'winning', 'winnipeg', 'winnipegarea',
#        'winnipeggers', 'winsulin', 'winter', 'winterproof',
#        'winterspring', 'wintertime', 'winwin', 'winwinyou', 'winä',
#        'wipe', 'wiped', 'wiper', 'wiping', 'wire', 'wired', 'wireless',
#        'wiring', 'wisconsin', 'wisdom', 'wise', 'wisely', 'wiser',
#        'wisest', 'wish', 'wished', 'wishing', 'wishlist', 'wit', 'witch',
#        'witchhunt', 'withdraw', 'withdrawal', 'withdraws', 'withdrew',
#        'witherspoon', 'witherspoonäôs', 'withholding', 'withholds',
#        'within', 'withings', 'withit', 'without', 'withoutä', 'withstand',
#        'withäîbut', 'witness', 'witnessed', 'witnessing', 'witty', 'wiz',
#        'wizard', 'wiä', 'wk', 'wkend', 'wknd', 'wks', 'wladimir', 'wld',
#        'wlean', 'wlk', 'wlots', 'wlp', 'wlung', 'wm', 'wmentally', 'wmy',
#        'wnearly', 'wneighbors', 'wnuts', 'wnutseed', 'wnutsseeds', 'wo',
#        'woah', 'wob', 'wobbly', 'wockhardt', 'woe', 'woefully',
#        'woesagain', 'woke', 'wolf', 'wolfe', 'wolfert', 'wolfville',
#        'wolverine', 'woman', 'womancentred', 'womantowoman', 'womanäôs',
#        'womb', 'wombtransplant', 'womenbut', 'womensee', 'womenshealth',
#        'womenäôs', 'wonder', 'wondered', 'wonderful', 'wondering',
#        'wonderland', 'wonk', 'wonkblogs', 'wonky', 'wont', 'wonton',
#        'wonäôt', 'woo', 'wood', 'woodcock', 'wooden', 'woodland',
#        'woodleys', 'woodstock', 'woodwork', 'woohoo', 'wooing', 'wool',
#        'wooly', 'woos', 'woot', 'woozy', 'word', 'wore', 'work',
#        'workaholic', 'workand', 'workaround', 'workarounds', 'workbased',
#        'workday', 'worked', 'worker', 'workersäô', 'workforce', 'workgt',
#        'working', 'workingage', 'workingyou', 'worklife', 'workload',
#        'workout', 'workoutyou', 'workoutäîit', 'workoutäô', 'workouä',
#        'workplace', 'workrelated', 'workshop', 'worksites', 'workspace',
#        'workwardrobe', 'workweek', 'world', 'worldclass', 'worldwide',
#        'worldäôs', 'worm', 'worminspired', 'worn', 'worried', 'worrier',
#        'worrisome', 'worry', 'worrying', 'worse', 'worsen', 'worsened',
#        'worsening', 'worsens', 'worship', 'worst', 'worstever',
#        'worsthit', 'wort', 'worth', 'worthless', 'worthwhile', 'worthy',
#        'wothers', 'would', 'wouldbe', 'wouldcould', 'wouldnt',
#        'wouldnäôt', 'wouldve', 'wound', 'wounded', 'wounding', 'wout',
#        'wow', 'wowsome', 'wowworthy', 'wpesto', 'wprevention',
#        'wproblems', 'wprotein', 'wrangle', 'wrap', 'wrapped', 'wrapper',
#        'wrapping', 'wreak', 'wreaks', 'wreck', 'wrecked', 'wrecker',
#        'wrecking', 'wrench', 'wrenching', 'wresolutions', 'wrestle',
#        'wrestled', 'wrestler', 'wrestling', 'wresultsä', 'wrha', 'wright',
#        'wrigley', 'wrinkle', 'wrinkled', 'wrising', 'wrist', 'wristband',
#        'write', 'writebol', 'writedowns', 'writer', 'writes', 'writeup',
#        'writing', 'written', 'wrong', 'wrongbodypart', 'wrongdoing',
#        'wrongful', 'wrongheaded', 'wrongly', 'wrote', 'wrought', 'wsauce',
#        'wscope', 'wseafood', 'wseeing', 'wsj', 'wsjnbc', 'wsjs', 'wsjtv',
#        'wslimforlife', 'wsmall', 'wsocial', 'wsomeone', 'wspecial',
#        'wspicä', 'wt', 'wtc', 'wth', 'wthe', 'wthis', 'wto', 'wtravel',
#        'wtreats', 'wtv', 'wtype', 'wu', 'wuerker', 'wunderkind', 'wunmet',
#        'wusc', 'wuscs', 'wut', 'wva', 'wveggies', 'wvinegaritäôs',
#        'wvitamin', 'ww', 'wwalnutargula', 'wwater', 'wweight', 'wwhole',
#        'wwine', 'wwomen', 'wwwarmyofwomenorg', 'wy', 'wyatt', 'wyden',
#        'wynne', 'wyoming', 'wyou', 'wyour', 'wypr', 'wä', 'xalkori',
#        'xanax', 'xanxrelated', 'xarelto', 'xbox', 'xchangescott',
#        'xeloda', 'xena', 'xfire', 'xinhua', 'xjack', 'xl', 'xmas', 'xo',
#        'xolair', 'xr', 'xray', 'xrays', 'xtl', 'xtreme', 'xylitols', 'ya',
#        'yaaawn', 'yacranberrypoached', 'yael', 'yahoo', 'yale', 'yalkin',
#        'yall', 'yalof', 'yam', 'yamanaka', 'yan', 'yang', 'yankee',
#        'yankovic', 'yanni', 'yard', 'yare', 'yarn', 'yasmin', 'yasso',
#        'yawn', 'yawner', 'yawning', 'yay', 'yaz', 'yday', 'yea', 'yeah',
#        'year', 'yeardespite', 'yearend', 'yearlong', 'yearly', 'yearold',
#        'yearolds', 'yearround', 'yearslong', 'yearslost', 'yearsold',
#        'yearsäô', 'yearthat', 'yearäôs', 'yearäôsresolutions', 'yeast',
#        'yeastand', 'yeasty', 'yehuda', 'yell', 'yelling', 'yellow',
#        'yellowfever', 'yellowknife', 'yellowstone', 'yellowtinted',
#        'yelp', 'yemen', 'yen', 'yep', 'yepyou', 'yer', 'yes', 'yesand',
#        'yesno', 'yesterday', 'yet', 'yield', 'yikes', 'yin', 'yip',
#        'yippee', 'ymca', 'yme', 'yo', 'yoga', 'yogaenthusiast',
#        'yogaforweightloss', 'yogalosophy', 'yoganandas', 'yogapilates',
#        'yogascape', 'yogavirginthese', 'yogaäîtraditionally', 'yoghurt',
#        'yogi', 'yogini', 'yogurt', 'yogurtandspice', 'yogurtdill', 'yolk',
#        'yong', 'yoplait', 'york', 'yorker', 'yorkers', 'yorkshire',
#        'yosemite', 'youd', 'youe', 'youhealth', 'youhealthier', 'youll',
#        'youloved', 'young', 'younger', 'youngerat', 'youngerlooking',
#        'youngest', 'youngster', 'younguns', 'youre', 'yourhead',
#        'yourheart', 'yourlist', 'yourrrre', 'yourseä', 'yous', 'youself',
#        'yout', 'youth', 'youthdrug', 'youthful', 'youthink',
#        'youthpromoting', 'youtoons', 'youtube', 'youtubeinspired',
#        'youve', 'youwhat', 'youä', 'youäôd', 'youäôll', 'youäôre',
#        'youäôve', 'youäù', 'yoyo', 'yoä', 'yr', 'yrold', 'yrolds', 'yuck',
#        'yuk', 'yukon', 'yum', 'yummiest', 'yumminess', 'yummm', 'yummmm',
#        'yummy', 'yumthose', 'yup', 'yusuf', 'yvonne', 'ywca', 'yä',
#        'zaatar', 'zach', 'zaire', 'zambia', 'zamboni', 'zanett', 'zap',
#        'zappas', 'zapped', 'zapping', 'zara', 'zarway', 'zayid', 'zeal',
#        'zealand', 'zealandäôs', 'zebra', 'zebrafish', 'zeke', 'zellweger',
#        'zen', 'zendaya', 'zeneca', 'zerbaxa', 'zero', 'zerocalorie',
#        'zeroing', 'zerowaste', 'zest', 'zesty', 'zeta', 'zetia', 'zeä',
#        'zgnx', 'ziad', 'zients', 'zilmax', 'zimmer', 'zimmerbiomet',
#        'zimmerman', 'zinc', 'zing', 'zinnia', 'zion', 'zip', 'ziplining',
#        'ziplock', 'zipped', 'zipper', 'zit', 'zitcausing', 'zithromax',
#        'zmapp', 'zmh', 'zocor', 'zod', 'zoetis', 'zohydro', 'zoku',
#        'zola', 'zombie', 'zombielike', 'zone', 'zoning', 'zoo', 'zoom',
#        'zoonotic', 'zopiclone', 'zts', 'zucchini', 'zucchinifilled',
#        'zucker', 'zuckerberg', 'zumba', 'zydelig', 'zyprexa', 'zzzs',
#        'zzzzz', 'zzzzzs', 'zzzzzä', '½yearold', 'ãââ', 'äa', 'äì',
#        'äìreach', 'äìsg', 'äî', 'äîemerson', 'äîincluding', 'äîleo', 'äï',
#        'äòa', 'äòat', 'äòbad', 'äòbuddyäô', 'äòcuredäô', 'äòdamagingäô',
#        'äòdeserveäô', 'äòdessertäô', 'äòdiet', 'äòepidemicäô',
#        'äòexcusesäô', 'äòfeeling', 'äògirlsäô', 'äògolden', 'äògrey',
#        'äòhow', 'äòi', 'äòif', 'äòinappropriateäô', 'äòitäôs', 'äòlittle',
#        'äòmeasles', 'äòmental', 'äòmoral', 'äòmorningafteräôpill',
#        'äòmrs', 'äòmy', 'äònews', 'äònormaläô', 'äòpaleo', 'äòpick',
#        'äòput', 'äòratioäô', 'äòselfinflictedäô', 'äòskinny', 'äòsolar',
#        'äòsticking', 'äòstigmaäô', 'äòstormtrooperäô', 'äòsugaräô',
#        'äòsuper', 'äòthe', 'äòwhat', 'äòwhen', 'äòwhy', 'äòyour', 'äô',
#        'äôs', 'äù', 'äùgood', 'äú', 'äúa', 'äúalisteräù', 'äúallergic',
#        'äúansweredäù', 'äúas', 'äúawesome', 'äúbeing', 'äúbreakfast',
#        'äúbuddyäù', 'äúcaesaräù', 'äúcelebrity', 'äúcleanäù', 'äúcäù',
#        'äúdancing', 'äúdateäù', 'äúdietäù', 'äúdoubling', 'äúeat',
#        'äúeveryoneäôs', 'äúeverything', 'äúfatäù', 'äúfitness', 'äúfood',
#        'äúfrom', 'äúfuture', 'äúget', 'äúi', 'äúif', 'äúin', 'äúits',
#        'äúitäôs', 'äújeopardyäù', 'äújump', 'äújunkäù', 'äújust',
#        'äúlife', 'äúmehäù', 'äúmonogamishäù', 'äúmyclothesaresnug',
#        'äúneedäù', 'äúnice', 'äúnormaläù', 'äúparents', 'äúpfi',
#        'äúprotein', 'äúreal', 'äúrefuses', 'äúriskyäù', 'äúseize',
#        'äúside', 'äústackäù', 'äústick', 'äúsuperbugsäù',
#        'äúthanksgiving', 'äúthe', 'äúthere', 'äútheyäôre',
#        'äúthreatening', 'äútäù', 'äúvaccines', 'äúwhen', 'äúwould',
#        'äúyou', 'éric', 'òï', 'ôèawareness', 'ùôè', 'üëçüòäù', 'üòä',
#        'üòéüéñüéö', 'üòïüëô'], dtype=object)

# %%
tfidf = tfidfVec.fit_transform(cleaned.tolist())

# %%
stemmedidf = tfidfVec.fit_transform(stemmed.tolist())

# %%
tfidfVec.get_feature_names_out()[0:1000]
# Out:
# array(['0000', '000058', '000306', '000935', '001201', '002431', '002432',
#        '004904', '005', '007', '01', '010130', '012524', '012806',
#        '013027', '015206', '02', '020210', '022201', '023452', '024657',
#        '024658', '025018', '025019', '025803', '03', '030411', '030437',
#        '030548', '030715', '031210', '031316', '031603', '032203',
#        '032827', '033150', '033404', '033443', '033742', '035457',
#        '035526', '035754', '035755', '04', '040512', '041101', '041248',
#        '041346', '041347', '041400', '041532', '041903', '042310',
#        '042444', '042925', '042926', '043053', '043419', '043712',
#        '043745', '044652', '05', '050704', '051615', '06', '064627', '07',
#        '070027', '08', '080027', '09', '090027', '093149', '0for3', '0g',
#        '10', '100', '1000', '10000', '100000', '1000000', '10000amonth',
#        '10000plus', '10000step', '100027', '1000apil', '1000convers',
#        '1000day', '1000pill', '1000s', '1003degre', '100calori',
#        '100daysofchang', '100fold', '100k', '100m', '100mile',
#        '100millionth', '100s', '100x', '100yearold', '101', '1011',
#        '1011am', '1012', '1015', '10169', '1017', '101st', '101yearold',
#        '102', '102share', '102yearold', '103', '1030a', '1031',
#        '103degre', '103yearold', '104', '104yearold', '105', '106',
#        '106000', '106g', '106k', '107', '108', '1081calori', '1089',
#        '109', '10a', '10am2pm', '10b', '10bn', '10day', '10hour', '10k',
#        '10m', '10mile', '10miler', '10minut', '10monthold', '10p',
#        '10pack', '10pe', '10petpt', '10pm', '10point', '10stone', '10th',
#        '10x', '10year', '10yearold', '11', '110', '1100', '11000',
#        '110000', '1105', '110yearold', '111', '11143', '1115', '11187',
#        '112', '11200', '112000', '1121', '11225', '112k', '112m', '112th',
#        '113', '1130', '113045', '1130a', '114', '1143', '114338', '1145',
#        '115', '1150', '115000', '115009', '11530', '115bn', '115day',
#        '115k', '115pet', '116', '116year', '117', '117000', '118',
#        '118000', '119', '11a', '11am', '11amest', '11ampst', '11bn',
#        '11m', '11p', '11pm', '11th', '11yearold', '12', '120', '1200',
#        '12000', '12000yrold', '120027', '120042', '1200am', '121', '1213',
#        '121314', '121950', '121ä', '122', '1226', '1229', '122m', '122pm',
#        '123', '1230', '1230230', '1230pm', '1238', '123b', '124', '124pm',
#        '125', '12500', '125000', '125m', '12600', '127', '127lbs', '128',
#        '128k', '12900', '12am', '12b', '12c', '12hour', '12k', '12m',
#        '12noon', '12pet', '12pm', '12week', '12year', '12yearold', '13',
#        '130', '1300', '13000', '1300bc', '130lb', '130pm', '131',
#        '131342', '1315', '131st', '132', '1323', '13241', '132lb', '133',
#        '1335', '134', '134bn', '135', '1350', '135920', '136', '137',
#        '138', '13b', '13dayold', '13for13', '13in2013', '13k', '13m',
#        '13pm', '13pound', '13yearold', '14', '140', '14000', '140000',
#        '1400calori', '1400calorieday', '14090', '140pound', '141425',
#        '141503', '1417', '142', '1421', '1422', '1427', '142b', '143',
#        '143000', '143507', '143614', '143910', '143k', '144416', '14497',
#        '145', '14500', '145809', '145lbs', '146', '14678', '147', '14810',
#        '149', '14bn', '14here', '14m', '14pound', '14th', '14year',
#        '14yearold', '15', '150', '1500', '15000', '150000', '150024',
#        '150034', '1500ados', '1500yearold', '150629', '15090', '150k',
#        '150m', '151000', '151008', '151100', '151108', '151135', '151139',
#        '1520lbs', '152312', '152333', '152402', '152419', '152427',
#        '152806', '153', '153014', '153040', '153106', '153449', '153509',
#        '153626', '153651', '153731', '153lbs', '153m', '154', '154505',
#        '154935', '155', '1550', '155000', '1552', '155454', '1557',
#        '155772', '157', '157k', '158', '15935', '15b', '15billionayear',
#        '15bn', '15g', '15hour', '15k', '15min', '15minut', '15mn',
#        '15plus', '15shre', '15th', '15year', '15yearold', '15yr', '16',
#        '160', '1600', '16000', '160110', '160120', '160149', '160410',
#        '160528', '160709', '160905', '161', '161234', '16153', '161k',
#        '162', '162152', '162217', '162407', '162452', '162506', '162549',
#        '162603', '162810', '162837', '162945', '163', '163401', '163525',
#        '163657', '163826', '163b', '164', '164001', '164318', '164332',
#        '164337', '164338', '164543', '164832', '165', '165827', '1658km',
#        '165m', '166', '167', '16834', '16bn', '16hour', '16pm', '16pound',
#        '16s', '16thcenturi', '16yearold', '17', '170', '1700', '17000',
#        '17000yr', '170107', '170119', '170221', '170308', '170543',
#        '171110', '171218', '171528', '171550', '171659', '171908', '172',
#        '172035', '172214', '172306', '172636', '172646', '172935',
#        '173050', '173431', '173921', '17453', '174623', '174729', '175',
#        '17500', '175021', '1750s', '175959', '176', '176000', '178000',
#        '17837', '179', '17b', '17k', '17m', '17thcenturi', '17yearold',
#        '18', '180', '1800', '18000', '180000', '180012', '18003182596',
#        '180037', '180056', '1800quitnow', '1800s', '1800yrold', '180216',
#        '180402', '180733', '180750', '180851', '180934', '181', '181038',
#        '181542', '181557', '181824', '182', '182302', '182619', '182917',
#        '183039', '183156', '183326', '183333', '1834', '1835', '183738',
#        '183814', '1839', '183954', '184', '184142', '184224', '184346',
#        '18450', '184624', '184816', '1849', '185037', '185153', '185208',
#        '185352', '185509', '185830', '185916', '185k', '18603', '1870s',
#        '188', '18884168333', '1889', '189', '18for18', '18inarow', '18th',
#        '18to64yrold', '18year', '19', '190', '1900', '19000', '190102',
#        '190155', '190432', '190742', '190923', '190m', '191025', '191131',
#        '1918', '191shre', '1920s', '192234', '192240', '1923', '192311',
#        '192317', '192424', '192439', '192527', '192534', '192535',
#        '192856', '193016', '193158', '194', '194029', '194030', '1940s',
#        '194212', '1943', '194958', '19497', '195', '1950', '1950s',
#        '1950sera', '1952', '195211', '195214', '195321', '1954', '195515',
#        '195533', '195546', '195612', '1957', '1959', '195m', '1960',
#        '1965', '1969', '197', '1970', '1970s', '1973', '1974', '1975',
#        '1976', '1979', '1980s', '1982', '1985', '1988', '1989', '199',
#        '1990', '1990s', '1991', '1994', '1995', '1996', '1997', '1998',
#        '1999', '19b', '19hour', '19minut', '19th', '19thcenturi',
#        '19yearold', '1amp2', '1bn', '1hour', '1in10', '1in20000', '1in5',
#        '1killer', '1kperpil', '1lb', '1m', '1million', '1minut', '1of3',
#        '1on1', '1p', '1pet', '1pm', '1pmet', '1q', '1ri', '1share1condom',
#        '1simplechang', '1st', '1stgrade', '1stperson', '1t', '1time',
#        '1year', '1yearold', '1yearonmar', '20', '200', '2000', '20000',
#        '200000', '20000x', '200013', '20002500', '2000s', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '200700x', '2008', '2009',
#        '200913', '200calori', '200g', '200k', '200m', '200mn', '200pound',
#        '201', '2010', '201009', '201022', '2011', '201139', '2011s',
#        '2012', '201211', '201215', '20123', '20125', '20126', '2012achi',
#        '2012adopt', '2012airport', '2012allerg', '2012annual', '2012aw',
#        '2012birthcontrol', '2012boost', '2012bore', '2012brow',
#        '2012carrot', '2012could', '2012do', '2012doubl', '2012dri',
#        '2012enter', '2012exhaust', '2012favorit', '2012find', '2012get',
#        '2012good', '2012health', '2012holiday', '2012how', '2012it',
#        '2012kendra', '2012kid', '2012know', '2012lupus', '2012more',
#        '2012most', '2012mother', '2012move', '2012musclebuild',
#        '2012need', '2012new', '2012old', '2012over', '2012pediatrician',
#        '2012pollen', '2012pregnant', '2012recip', '2012redhead', '2012rt',
#        '2012s', '2012sharon', '2012some', '2012soy', '2012spice',
#        '2012studi', '2012summer', '2012thanksgiv', '2012the',
#        '2012thirsti', '2012thirstythursday', '2012tip', '2012too',
#        '2012travel', '2012us', '2012veget', '2012vitamin', '2012walk',
#        '2012we', '2012weightloss', '2012were', '2012what', '2012yik',
#        '2012yippe', '2012youngest', '2012äúthanksgiv', '2013', '201314',
#        '20132014', '2013both', '2013hous', '2013most', '2013nation',
#        '2013ntsb', '2013recip', '2013the', '2013well', '2013world',
#        '2014', '201415', '201420', '2014a', '2014abort', '2014advertis',
#        '2014alex', '2014an', '2014as', '2014berkeley', '2014book',
#        '2014bpa', '2014brace', '2014braini', '2014british',
#        '2014childhood', '2014cholesterol', '2014compar', '2014concuss',
#        '2014court', '2014credibl', '2014cvs', '2014dementia', '2014do',
#        '2014doe', '2014dr', '2014dure', '2014ebola', '2014econom',
#        '2014endoflif', '2014even', '2014feder', '2014fight', '2014five',
#        '2014for', '2014fresh', '2014get', '2014global', '2014grief',
#        '2014have', '2014health', '2014heat', '2014heroin', '2014hospit',
#        '2014hot', '2014how', '2014in', '2014increas', '2014inject',
#        '2014investig', '2014is', '2014judg', '2014king', '2014leader',
#        '2014leadership', '2014liberian', '2014look', '2014matter',
#        '2014medicar', '2014mervyn', '2014militari', '2014more',
#        '2014most', '2014mothertochild', '2014new', '2014niger', '2014no',
#        '2014nonprofit', '2014offici', '2014on', '2014ope', '2014open',
#        '2014paleontolog', '2014parent', '2014pennsylvania', '2014perdu',
#        '2014physic', '2014quarantin', '2014reaction', '2014recip',
#        '2014remak', '2014rt', '2014s', '2014salti', '2014sam',
#        '2014scientist', '2014smaller', '2014someon', '2014studi',
#        '2014the', '2014there', '2014think', '2014three', '2014tri',
#        '2014un', '2014up', '2014us', '2014use', '2014video', '2014we',
#        '2014wed', '2014well', '2014what', '2014when', '2014who',
#        '2014with', '2014world', '2014äîinclud', '2015', '201518', '20155',
#        '2015as', '2015challeng', '2015fact', '2015if', '2015readi',
#        '2015rt', '2015s', '2015to', '2016', '2017', '2018', '201949',
#        '2020', '202000', '2022', '2024', '202411', '2025', '2026', '2030',
#        '2033', '2039', '203925', '204', '2040', '204241', '204533',
#        '204546', '204804', '205', '2050', '205445', '206', '208',
#        '20hour', '20k', '20m', '20minut', '20monthold', '20plus', '20s',
#        '20someth', '20th', '20week', '20x', '20year', '20ä', '20äô', '21',
#        '2100', '21000', '210249', '210258', '210705', '210720', '2110',
#        '211003', '211150', '211337', '211451', '211529', '2119', '211b',
#        '212', '212602', '213', '213040', '213359', '213400', '213452',
#        '213608', '213735', '213750', '214', '214029', '214404', '214603',
#        '214607', '214lbs', '215', '215007', '215027', '218m', '219',
#        '21bn', '21d', '21day', '21minut', '21st', '21stcenturi', '21x',
#        '21year', '21yearold', '22', '220', '22000', '220000', '220017'],
#       dtype=object)

# %%
cleaned.tolist()
# Out:
# ['ebola exposure cdc worker remains well',
#  'pregnant woman taken life support ireland',
#  'money icebucketchallenge still flowing al association leader remain awestruck gush goodwill',
#  'caramel apple recalled listeria death',
#  'ice bucket challenge still rain buck al',
#  'following mistake possible exposure cdc ebola lab health involved staff monitored 21 day',
#  'cdc report possible ebola exposure containment lab',
#  'stressfueled indulgence dont bring joy',
#  'delayed concussion common tricky',
#  'gay group decry fda rule requiring sex give blood',
#  'fda plan ease ban blood donation gay men',
#  'fda proposes easing ban blood donation gay men',
#  'nearly 2 million people choose obamacare',
#  'beyond narcan lifesaving heroin antidote isnt cure',
#  'joan lunden see finish line cancer battle',
#  'joan lunden see finish line cancer battle',
#  'deadly 2015 ebola rampage africa stopped',
#  'boy rare disease donates toy ucla hospital',
#  'secret world oldest yoga teacher dont believe age',
#  'obamacare number difference year make',
#  'california get worst whooping cough outbreak decade',
#  'aging tsunami crisis grows search help',
#  'whats 104yearolds formula longevity',
#  'star goalie new role inspires others tourette',
#  'one woman make difference ebola',
#  'aging tsunami montana aging crisis take village',
#  'flu case surge u',
#  'meet four people lost 100 pound kept',
#  'flu season early start year cdc',
#  'caramel apple linked five death cdc say',
#  'caramel apple linked 5 death cdc say',
#  'could christmas worsen ebola spread',
#  'cheap old car might carry deadly cost teen',
#  'one drug ebola treatment pipeline',
#  'could ibuprofen extend life human',
#  'baby worst disease youve never heard',
#  'air pollution may nearly double autism risk',
#  'new stroke treatment removing clot limit disability',
#  '103yearold doctor longevity exercise overrated',
#  'fed file murder charge fungal meningitis outbreak',
#  'smartphone controlled hand offer assisted control',
#  'transgender teacher joy heartbreak life woman',
#  'yes lose weight breathing study',
#  'arrest made meningitis outbreak killed 60',
#  'childrens cartoon rife death murder study',
#  'childrens cartoon rife death murder study',
#  'childrens cartoon rife murder study',
#  'u doctor support assisted suicide survey',
#  'mindcontrolled robot arm win rockpaperscissors',
#  'strong start million sign obamacare',
#  'never young seeking early test alzheimers',
#  'fda warns ultrasound keepsake image',
#  'u kid favor ecigarettes traditional one',
#  'mother surprise quad luckiest mom whole world',
#  'new test detects heart disease risk black woman',
#  'skin cancer indoor tanning sends hundred er',
#  'angelina jolies chickenpox serious adult',
#  'whats wrong wyatt baby disease baffle parent',
#  'toddler finally hears mom voice thanks implant',
#  'misinformed prenatal test high failure rate',
#  'single ebola outbreak give deadly disease new life',
#  'food help fight flu',
#  'thistown may hold secret longevity',
#  'dude watch men really idiotic',
#  'nurse trial forcefeeding case guantanamo',
#  'joint pain interrupt ebola vaccine trial',
#  'obese starving girl see healthy future',
#  'burning candle u kid lack sleep',
#  'breast cancer prevention last decade study find',
#  'u nurse watched nih ebola',
#  'biggest loser trainer avoid holiday weight gain',
#  'bad luck men poor semen poorer health',
#  'new hpv vaccine broadens cancer protection',
#  'phthalates food packaging linked lower iq',
#  'phthalates food packaging linked lower iq',
#  'breast cancer patient may get longer radiation needed',
#  'much radiation woman could get le breast cancer',
#  'high risk 100fold ebola rate health care worker',
#  'huge ebola risk face sierra leone health care worker',
#  'could chemical bpa raise blood pressure',
#  'childhood illness fell mighty hockey player',
#  'billionaire paul allen pledge million cell science',
#  '2020 hindsight doc sent ebola patient home say care appropriate',
#  'ebola czar return private sector',
#  'want easy healthy breakfast try 3 recipe',
#  'obama visit walter reed hospital sore throat',
#  'oxygen therapy hot air treatment doesnt pas test',
#  'oxygen therapy hot air treatment doesnt pas test',
#  'testing incurable disease would want know',
#  'use unproven stem cell therapy questioned',
#  'technoference hurting relationship',
#  'season flu vaccine le effective',
#  'mutant flu still need vaccine',
#  'quit smoking destroys male chromosome',
#  'whooping cough epidemic get used',
#  'bother getting flu shot need know',
#  'dallas spent 27k care ebola nurse dog',
#  'young cancer patient benefit teenfriendly treatment center',
#  'cdc warning flu virus mutate evade current vaccine',
#  'unprecedented drug may help heal damaged spine',
#  'terminally ill basketball player sign hospice care',
#  'growth u health spending lowest record',
#  'obamacare bump 10 million got insurance survey show',
#  'new label clarify prescribing pregnancy',
#  'ibm help donate computer power fight ebola',
#  'divorce rate lower u',
#  'dr nancy snyderman sorry violating ebola quarantine',
#  'radiation danger kid may get unneeded xrays',
#  '8 percent american depression treated',
#  'fda reconsiders ban gay donating blood',
#  'obama praise u ebola effort',
#  'obama praise u ebola effort',
#  'death minute 30 year union carbide disaster',
#  'obama praise u ebola effort',
#  '4yearold boy suffers mysterious stroke',
#  'montana clinic help special delivery',
#  'u name 35 ebolacertified hospital',
#  'oversleep blame dna',
#  'circumcision benefit outweigh risk cdc say',
#  'hiv patient getting sicker qualify housing',
#  'hospital error drop saving 50000 life government',
#  'headed disaster know traumatic brain injury',
#  'world aid day aid activist new feminist',
#  'room optimism report ebola progress',
#  'doctor blame scooter jump toyrelated injury',
#  'u baby sleep unsafe condition report find',
#  'ebola death toll leap higher',
#  'liberia suspends election campaigning ebola',
#  'advises ebola survivor abstain sex three month',
#  'advises ebola survivor abstain sex three month',
#  'sugar rehab new treatment notsosweet addiction',
#  'could plane help save ebola patient',
#  'first human ebola vaccine trial show seems work',
#  'gmo cattle produce serum fight hantavirus',
#  'grieving family hears son heart beat anothers chest',
#  'calling quits american smoking hit 50 year low',
#  'half million sign obamacare first week',
#  'family hears dead son heart beat inside chest organ recipient',
#  'ryan reynolds michael j fox team parkinson',
#  'together u ebola survivor meet today',
#  'toddler switched birth exchanged',
#  'mom drive knowing take key',
#  'american hiv missing treatment cdc say',
#  'american hiv skip treatment cdc say',
#  'incredible gift man thankful double arm transplant',
#  'many calorie thanksgiving feast',
#  'watch live bilateral arm transplant news conference',
#  '6 thing adoptive parent right',
#  'pizza popcorn included new fda calorie label rule',
#  'le painful mammogram new device may help',
#  'fda order calorie count restaurant menu',
#  'fda warns device say spread cancer',
#  'tale two outbreak congo conquered ebola',
#  'holiday surprise mom dad slipping away',
#  'bird flu force church hold drivein service',
#  'ebola mapper track epidemic real time',
#  'troop spend 21 day ebola quarantine',
#  'mali confirms new ebola case',
#  'ebola epidemic even close un official say',
#  'violence woman unacceptably high expert say',
#  'today geist daly undergo live testicular exam',
#  'report plague outbreak madagascar',
#  'hidden downside glutenfree diet',
#  'zoning really bad narcolepsy video go viral',
#  'ripped apart men experience pain childbirth',
#  'watch men experience pain childbirth',
#  'new ebola vaccine trial start baltimore',
#  'kiss bubble baby promising new treatment',
#  'ebola give west african temporary respite u',
#  'woman boss prone depression study',
#  '5 million stroller recalled fingertip amputation',
#  'obesity costing global economy trillion',
#  'texting neck hunching phone stress spine',
#  'cop kill study find biggest heart risk',
#  'new brittany maynard video call action',
#  'banker culture may encourage cheating study find',
#  'study reveals texting put pressure spine',
#  'cuban doctor catch ebola',
#  'deceased woman hair salon test negative ebola',
#  'hair salon decontaminated amid ebola concern',
#  'brittany maynard breathes new life aidindying cause',
#  'soft drink firm still target kid report find',
#  'u africa need ebolaready hospital expert say',
#  'sister find brother shirtless dead snow',
#  'cost treat ebola 1 million two patient',
#  'cdc shelf controversial obesity website',
#  'well hotel maid really clean',
#  'rare resource doctor died ebola big loss',
#  'tick spit newest weapon fight cancer',
#  'bad credit linked higher heart attack risk',
#  'whats kiss 80 million bacteria',
#  'surgeon death teach u treating ebola',
#  'doctor ebola death werent able get',
#  'gave everything ebolainfected surgeon dy nebraska',
#  'gave everything ebolainfected surgeon dy nebraska',
#  'gave everything doctor discus death ebola patient',
#  'doctor discus death ebolainfected surgeon',
#  'school offer veggie lunch kid dont bite',
#  'ebola patient treated nebraska died',
#  'hair care top stylist creates wig kid cancer',
#  'watch live doctor discus death ebola patient dr martin salia noon et',
#  'home cook eat better new study find',
#  'whats kiss 80 million bacteria',
#  'u begin screening traveler mali ebola',
#  'snack tax navajo lawmaker ok price hike junk food',
#  'energy drink deadly young child study',
#  '4 thing get wrong metabolism',
#  'disappearing boy wont landon eat drink',
#  'ebola surgeon extremely critical u hospital',
#  'ready go ebolastricken surgeon land u',
#  'obamacare 20 new 2015 enrollment phase roll',
#  '26 way avoid getting sick winter',
#  'ready ebolastricken surgeon head u',
#  'deadly stigma lung cancer killing nonsmoker',
#  'mom daughter give birth hospital day',
#  'hero son ebola doctor praise dad',
#  'afraid needle steelstudded pill could help',
#  'ebola video game training medic far hazard',
#  'clean home could mean clean conscience',
#  'arkansas gov snowplow parent pardoning son',
#  'new ebola patient coming u treatment',
#  'dont lick stick dirty contact cause eye infection',
#  'sleeping confession ambien zombie',
#  'boy born without thumb get hand transformed',
#  'husband sleep apart',
#  'doctor without border help test ebola drug',
#  'thing tend change quickly ebola',
#  'im scapegoat sterilization death doctor say',
#  'back fight american doctor help fightebola',
#  'semen boost aid virus study find',
#  'watch live senate hearing ebola',
#  'coming senate hearing ebola',
#  'duncan family atty announce settlement',
#  'ebola kill nurse mali worse spread feared',
#  'watch live family thomas eric duncan hold news conference',
#  'diet dont work long review show',
#  'homeless brace cold',
#  'mom handmade disney costume help shy girl blossom',
#  'doctor cured ebola released cheer hug',
#  'today healthy ebolastricken doctor leaf hospital',
#  'hickox frustrated nursing school turned away boyfriend',
#  'watch live ebolafree doctor craig spencer speaks',
#  'coming last u ebola patient leaf hospital',
#  'mapping criminal mind',
#  'mom auction ring help pay adoption',
#  'fighting stigma aid counselor turn effort ebola',
#  'eight woman die sterilization surgery india',
#  'dad build costume help sick infant feel brave',
#  'ebolafree america last u patient cured',
#  'medicare plan pay lung cancer screening',
#  'administration lower obamacare sight',
#  'scrub go hightech',
#  'thousand child risk laundry pod study',
#  'marshall plan west africa 6 billion ebola go',
#  'snooze lose tip getting good night sleep',
#  'moon nurse help baby intensive care dream big',
#  'safe eat tuna fish every day',
#  'million dollar question cant sleep',
#  'science childrens sleep',
#  'teen arent taking sport injury seriously study',
#  'republican congress cant gut obamacare',
#  'autism advocate welcome seinfelds disclosure',
#  'autism advocate welcome seinfelds disclosure',
#  'uk mom opts end life disabled child',
#  'allergic penicillin youre probably',
#  'viral baby announcement includes cooky scream',
#  'texas ebola outbreak ended',
#  'people allergic penicillin researcher',
#  'texas ebola outbreak end',
#  'pokey robot creates ghostly presence demand',
#  'rt tale chucking big job new lady porn rt whats really causing woman burn 30',
#  'holiday coffee worth calorie',
#  'look inside u ebola facility monrovia',
#  'ebola nurse amber vinson defends decision fly',
#  'try bizarre trick cure carsickness kid',
#  'appy baby 8 innovation help new parent',
#  'colon cancer new face getting younger',
#  'obama seek 6 billion ebola fight',
#  'men 50 miss important medical test study',
#  'could air pollution help cause adhd',
#  'mom charged killing autistic son heard voice',
#  '8 million u woman skip cervical cancer screening',
#  'mom charged killing autistic son heard voice',
#  'nurse leaf hospital still mourning executed dog',
#  'guerrilla dad empower kid dont pay college',
#  'autistic boy killing desperate cry help',
#  'nofly zone ebola quarantine rule keep researcher away',
#  'maynards death brain cancer lethal',
#  'mom accused tossing son bridge blogged autism',
#  'vatican official denounces brittany maynards death',
#  'thousand break ebola quarantine find food',
#  'home test new option colon cancer screening',
#  'world bank ebola battle need help asia',
#  'politically hot attractiveness decided party line',
#  'pregnancy doesnt keep running',
#  'ebola crisis american help',
#  'breakthrough nose spray ebola vaccine protects monkey',
#  'brittany maynards death ethical choice',
#  'doctor dy ebola sierra leone',
#  'baby talk gap mom may talk girl',
#  'brittany maynard dy oregon',
#  'abundance politics ebola nurse slam christie',
#  'un worker flown france ebola treatment',
#  'cdc fueling antifat bias workplace',
#  'scared willing doctor heading africa fight ebola',
#  'eluding ebola skill may matter gear',
#  'ebola controversy harmed fight',
#  'lead poisoning hidden danger shooting range',
#  'welcome back bentley ebola nurse dog reunited',
#  'brittany maynard dan diaz love story',
#  'gerber accused false claim baby formula',
#  'ambassador power ill follow strictest protocol ebola',
#  'maine gov police protect kaci hickox',
#  'class shake effect social medium',
#  'execution date set delusional murderer texas',
#  'nyc actively monitoring 117 people ebola risk',
#  'nbcs kate snow covering ebola story mom',
#  'kaci hickox still waiting hear state maine',
#  'kari hickox still waiting hear state maine',
#  'brittany maynard may stay longer planned say',
#  'ebola kill study find deadly sign',
#  'gene trawl haul new find autism m',
#  'dozen volunteer come back safe ebola hot zone',
#  'medical expert seek ban oncampus tanning',
#  'skin cancer u student tan campus top college',
#  'run divorce led nyc marathon',
#  'obama speaks health worker ebola frontlines',
#  'fda approves new meningitis b vaccine',
#  'obama meet health worker fighting ebola',
#  'ministomachs let scientist study ulcer lab dish',
#  'amb power ebola screening procedure extremely important',
#  'amb power possible quarantine obey law',
#  'amb power ebola screening procedure extremely important',
#  '4 stroke symptom watch',
#  'hagel approves 21day ebola quarantine troop',
#  'defiant ebola nurse bullied politician',
#  'nurse wont obey ebola quarantine report',
#  'oh boy couple 12 son expecting baby 13',
#  'lazy chronic fatigue real brain scan show',
#  'aid group plead donation ebola orphan',
#  'ebolafree amber vinson day celebration gratitude',
#  'ebolafree nurse amber vinson leaf emory hospital',
#  'woman asked stop breastfeeding obgyn office',
#  'texas medical staff apologizes breastfeeding mother',
#  'ebola bully schoolyard panic new contagion',
#  'watch live dallas nurse amber vinson speaks 1p et',
#  'australia shuts border people ebolahit nation',
#  'radicalized prone isi internet recruiting',
#  'quarantine quarantine doctor weigh',
#  'four category risk cdc tweak ebola guideline',
#  'chance army quarantine troop back ebola zone',
#  'christie quarantine going take risk',
#  'marvel superheroes battle bullying new comic',
#  'critic christie defends nurse quarantine',
#  'cant hiv vaccine rushed like ebola',
#  'ebola research get boost crowdfunding',
#  'ebola scare hit dallas resident hunkered',
#  'free go nurse quarantined suspected ebola released',
#  'drug company double ebola vaccine',
#  'new york governor lay ebola rule home quarantine',
#  'nurse lawyer promise challenge ebola quarantine',
#  'bioethicist 7 reason ebola quarantine bad idea',
#  'fed urge state go overboard ebola',
#  'ebola quarantine unintended consequence',
#  'new home test could help fight colon cancer',
#  'sweet special cocoa drink may reverse memory loss',
#  'christie defends ebola quarantine nurse blast treatment',
#  'new york city ebola patient receives blood writebol',
#  'ebola nurse quarantined nj criticizes rule',
#  'ebola worker test negative stay quarantine nj',
#  'girl shave head support 5yearold sister remission',
#  'worker treated ebola hospitalized nj fever',
#  'worker treated ebola isolation fever nj',
#  'worker treated ebola isolation fever nj',
#  'brittany maynards bucket list beckons grand canyon',
#  'bioethicist hotel quarantine ebola hero',
#  'new york new jersey quarantine ebola doctor',
#  'ebola survivor rick sacrum would go back liberia',
#  'nyc ebola patient stable condition official say',
#  'cured ebola nina pham anxious see family dog',
#  'new york mayor delivers update ebola patient',
#  'watch live briefing discharge ebola patient nina pham 1130a et',
#  'virus free ebola infected nurse nina pham go home',
#  'coming nyc mayor update public ebola case',
#  'hear gossip good',
#  'watch live mayor de blasio hold briefing nyc ebola patient',
#  'hear gossip good study say',
#  'ebola survivor dont judge nyc doctor virus',
#  'prepared worst inside bellevues ebola unit',
#  'new york ebola patient craig spencer',
#  'dont panic ebola wont become epidemic new york',
#  'epidemic fear shrug jitter nyc ebola case',
#  'epidemic fear shrug jitter nyc ebola case',
#  'brooklynite reacts first ebola case new york',
#  'ebola diagnosis shrug fear new york city',
#  'gov cuomo new york ready handle ebola',
#  'doctor test positive ebola new york city',
#  'compelled ebola survivor tell went liberia',
#  'single case ebola confirmed west africa mali',
#  'microsoft cofounder bump ebola effort 100 million',
#  'disrespectful brittany maynard slam doctor remark',
#  'arsenic glutenfree food worried',
#  'new york check suspected ebola patient',
#  'nurse ebola recovered quickly',
#  'favorite 10 food avoid list',
#  'watch live texas task hold hearing ebola preparedness',
#  'there uber flu shot',
#  'lesson learned nbc news freelancer ebola story',
#  'overweight woman tend earn le pay study',
#  'bite sharing cake make feel better',
#  'new testing start experimental ebola vaccine',
#  'testing start another new ebola vaccine',
#  'young healthy nbc news freelancer survived ebola',
#  'ashoka mukpo statement today joyful day',
#  'fed probe medical device possible cyber flaw',
#  'ebola aware cdc step traveler monitoring',
#  'tb even worse thought say',
#  'watch live medical official discus ebola patient ashoka mukpos treatment',
#  'dangerous drug still found recalled supplement',
#  'heartbreak one mom chooses new name',
#  'ebola check newark passenger landed fever',
#  'ebola czar first day meeting white house team',
#  'tire company liberia beat back ebola',
#  'ebola could control six month red cross',
#  'nurse ebola upgraded good condition',
#  'young basketball player brain disease play one last game',
#  'spanish nurse free ebola doesnt know dog',
#  'caring kill human cost ebola',
#  'pollution harm baby second trimester',
#  'fave horror flick say',
#  'report paralyzed man walk nerve cell transplant',
#  'report paralyzed walk nerve cell transplant',
#  'ebola vaccine trial aim january rollout',
#  'poll 45 worry family member could contract ebola',
#  'infection protection new ebola guideline stress gear ritual',
#  'microsoft offer cloud tool fight ebola',
#  'american fight liberian orphan amid ebola scare',
#  'ebola coincidence amber vinson neighbor also knew duncan',
#  'texas hospital presbyterian nurse hospital safe',
#  'every last penny booming funeral business',
#  'watch live dallas nurse hold briefing ebola care',
#  'apps could screen glaucoma doctor cant',
#  'ebola america fever broken',
#  'former nurse helped daughter die dignity',
#  'dozen cleared ebola monitoring dallas',
#  'viagra good sex live heart',
#  'cdc update ebola protocol anxiety rise',
#  'reheated pasta really healthier doctor weighs',
#  'beyond brittany assisted suicide happen every state insider say',
#  'meet couple battling male female breast cancer',
#  'canada ship experimental ebola vaccine',
#  'new clue kid wholegene scan analyzes mystery illness',
#  'hidden cure people ebolaproof blood could save life',
#  'texas ebola hospital executive fell short',
#  'suiting ebola cdc plan new gear guideline',
#  'ebola gear high demand',
#  'red wine bath knicks stoudemire say help recovery',
#  'dallas ebolahospital worker isolated carnival cruise',
#  'ebola codiscoverer crisis avoidable',
#  'ebola fear factor america need viral reality check',
#  'cdc vinson typical symptom ebola ohio',
#  'ebola nurse felt funny travel cdc',
#  'hows fed reveal latest dallas nurse case',
#  'hows fed reveal latest dallas nurse case',
#  'coming doctor give update ebola nurse condition',
#  'watch live national institute health hold briefing ebola patient',
#  'ebola crisis american help',
#  'texas ebolahospital worker caribbean cruise',
#  'who charge america battle ebola',
#  'ebola victim nina pham speaks hospital',
#  'obama address ebola travel ban',
#  'tulane looking rapid ebola test',
#  'texas presbyterian employee defends hospital',
#  'third ebola vaccine get cash infusion u',
#  'ebola health sleuth seek ohio bridal shop customer',
#  'ebolastricken nurse friend shes hero',
#  'health official grilled congress ebola mistake',
#  'health official grilled congress ebola mistake',
#  'faa administrator address travel ban amid ebola scare',
#  'speed dating help mom friend connect',
#  'brittany maynard live well death close',
#  'say youre sorry cdc director grilled ebola mistake',
#  'close home ebola nurse didnt venture far visit',
#  'teal pumpkin make halloween safer food allergy',
#  'ebola richness embarrassment lesson learned',
#  'watch live ohio county official hold briefing ebola concern 1030a et',
#  'watch live cleveland hospital official hold briefing ebola concern 930a et',
#  'watch live cleveland hospital official hold briefing ebola concern',
#  'youll pull ebola patient tell texas nurse',
#  'bad ebola get even expert dont know',
#  'bioethicist 10 thing america need ebola',
#  'fast ebola spread',
#  'google add cloud power cancer genome research',
#  'watch live kent state university hold press conference ebola',
#  'sweet kind ebolastricken nurse flew plan wedding',
#  'cleveland dir health ebola patient visiting plan wedding',
#  'kent state relative ebola nurse told stay away',
#  'kent state relative ebola nurse told stay away',
#  'ohio relative ebola nurse told stay home',
#  'watch live briefing ebola patient passed cleveland airport',
#  'dont breastfeed essay go viral',
#  'watch live cdc hold briefing ebola 1p et',
#  'human trial underway ebola vaccine',
#  'ebola search widens flight taken infected nurse',
#  'unaware pregnancy woman give birth twin',
#  'michigan child dy enterovirus',
#  '100k robot new warrior fight ebola',
#  'vision quest stem cell treat blinding disease',
#  'happy camper ebola patient dog get tlc',
#  'tingleheads say video help sleep',
#  'texas official second health care worker ebola',
#  'second texas health care worker test positive ebola',
#  'second texas health care worker test positive ebola',
#  'justice stop part texas abortion law',
#  'cdc promise special ebola response team',
#  'boy rare disease brain rewired',
#  'cdc detail enhancement ebola fight',
#  'cdc develops faster new test enterovirus d68',
#  'watch live health official discus latest ebola battle plan',
#  'coming health official discus latest ebola battle plan',
#  'study link skimpier suit rise skin cancer',
#  'ebolainfected nurse say well',
#  'teen saved transplant killed superbug',
#  'cant magic blood ebola',
#  'watch live cdc hold briefing ebola 3p et',
#  'predicts 10000 ebola case week',
#  'change ebola epicenter may slowing outbreak',
#  'nbc news freelancer ebola grateful good vibe',
#  'ebola kill un medic german hospital',
#  'perk tech giant pay woman freeze egg',
#  'know ebola travel insurance',
#  'ebola survivor brantly donates blood stricken nurse',
#  '5 passenger flu symptom taken jet boston',
#  'bentleys fate dallas nurse dog face ebola isolation',
#  'old old trick treat',
#  'american ebola survivor dont let fear take hold',
#  'cdc chief rethink ebola infection control plan',
#  'looking symptom google doctor',
#  'watch live cdc hold briefing ebola noon et',
#  'leaving liberia ebola check europe gateway u',
#  'decontamination begin new ebola patient home',
#  'official blame breach protocol new ebola case',
#  'health care worker show concern ebola preparedness',
#  'possible ebola case reported lax',
#  'texas caregiver confirmed second u ebola case',
#  'spanish nurse infected ebola make progress',
#  'heroic texas health worker test positive ebola',
#  'heroic health worker becomes second u ebola case',
#  'watch live official discus second u ebola case',
#  'coming official discus second u ebola case',
#  'second case texas health worker test positive ebola',
#  'texas health care worker test positive ebola hospital',
#  'michigan child dy enterovirus d68 hospital say',
#  'jfk begin implementing ebola screening protocol',
#  'new york jfk airport begin ebola screening program',
#  '10 thing reduce breast cancer risk',
#  'fever free man flash temp ebola isolation ward',
#  'pink drill bit bring complaint komen tie fracking',
#  'new york jfk airport begin ebola screening program',
#  'behind schedule flu shot slowdown peeve pediatrician',
#  'gross college say pee shower save water',
#  'grim record ebola death toll top 4000 seven month',
#  'case enterovirus d68 california',
#  'case enterovirus californa',
#  'campaign boy brain tumor go global',
#  'baby risk parent car seat wrong',
#  'duncan family question hospital action',
#  'brantly heart broken duncan family',
#  'watch live spokesman family first ebola death u speaks',
#  'watch live ebola patient dr kent brantly speaks 5p et',
#  'watch live ebola patient dr kent brantly speaks',
#  'new lung ring hospital proposal happy ending',
#  'ebola nurse aide stable serious downturn',
#  'husband nurse aide stare ebola ward',
#  'u ebola victim didnt want resuscitation hospital',
#  'brittany maynard change righttodie debate',
#  'mom get epidural stage labor',
#  'ebola patient got high level care hospital say',
#  'vaccine guinea pig tiny cog ebola fight',
#  'ebola victim cremated health official say',
#  'exclusive first ebola vaccine trial start africa',
#  'kid embrace little girl fatal disease',
#  'cdc chief ebola thing like aid',
#  'ebola dog deserves sympathy human',
#  'cdc chief ebola biggest world health threat since aid',
#  'expert search ebola vaccine',
#  'death dignity newlywed pick day shell die',
#  'ebola vaccine trial wrap first phase december',
#  'virus panic expect ebola false alarm cdc say',
#  'nerve implant let patient feel artificial finger',
#  'cdc report new screening process 4 u airport',
#  'duncan family pastor boy worried fate',
#  'enterovirus d68 problem year cdc looking',
#  'trying jump start immune system mukpo doctor',
#  'case ebola ny hospital show preparation',
#  'frisco investigating possible ebola case',
#  'excalibur dog exposed ebola euthanized',
#  'watch live pastor speaks behalf dallas ebola patient family',
#  'ebola death doesnt change risk others',
#  'watch live doctor speaks dallas ebola patient',
#  'fivetime champ race 8 month pregnant',
#  'fda approves inhalable form insulin',
#  'migraine men laughed told man',
#  'know even base tan bad',
#  'unkindest cut vasectomy place plea deal',
#  '80000 die yearly excessive drinking',
#  'hospital using credit card data track patient',
#  'leap faith patient try labgrown organ',
#  'strep amputee get rare double arm transplant',
#  'ny tourist 02 bubonic plague scare dy',
#  'game changer could blood test predict breast cancer risk',
#  'big soda ban fizzle',
#  'robotic exoskeleton suit get fda approval',
#  'teething pain fda warns danger painkiller',
#  'drinking death 1 10 workingage death booze',
#  'let kid eat junk food',
#  'drastic action needed ebola say',
#  'couch potato could kill',
#  'needlefree flu vaccine preferred kid',
#  'know debbie downer stop trying cheer',
#  'could watching tv kill',
#  'bite club make luis suarez chomp',
#  'popular acne med cause allergic reaction fda',
#  'rt yuck rt vacationer beware hot tub pool may harbor many germ',
#  'quadriplegic move hand thinking',
#  'inconceivable mom im pregnant naturally',
#  'older mom may live longer',
#  'scientist face prison bogus hiv vaccine case',
#  'seventh grader facing blindness aim help others see',
#  'ohio mumps outbreak top whole u last year',
#  'cancer breakthrough could new tech end mammogram controversy',
#  'ebola deadly',
#  'face limb transplant allocated like organ',
#  'high goosebump new technology tell',
#  'pot schizophrenia genetic link',
#  'teen doesnt idolize kardashians',
#  '5 thing didnt know glutenfree diet',
#  'health spending set start growing faster',
#  'exsmokers come clean new cdc campaign',
#  'meet baby conceived live television',
#  'rossen report germ lurk airport plane',
#  'home run kid amputee play ball wounded warrior',
#  'lung transplant rule saved sarah final',
#  'dad dance disabled daughter touch heart',
#  'polio found sewage brazil little threat world cup',
#  'cdc reassigns head lab behind anthrax blunder',
#  'utensil help steady tremor',
#  'getting deadlier worstever ebola outbreak kill hundred',
#  'cdc deputy director speaks anthrax exposure',
#  'girl shed 37 pound surgery weight disorder',
#  'fda warns dangerous testosterone risk video via health',
#  'cdc anthrax exposure resulted breakdown safety protocol via',
#  'bald man grows full head hair',
#  'e coli outbreak big beef recall',
#  'rt science hotness strength endurance soccer worldcup2014 worldcup',
#  'playstation side effect dangerous blood clot',
#  'cdc anthrax blunder number could climb higher',
#  'horrific ebola outbreak totally control',
#  'trauma trouble billion actually help vet ptsd',
#  'five surprising herb damage liver',
#  'new warning testosterone blood clot leg',
#  'mom parent ask there gun house',
#  'cdc 75 scientist possibly exposed anthrax',
#  'debunked 5 lightning myth could kill',
#  'velveeta recalled 12 state',
#  'cdc 75 scientist possibly exposed anthrax',
#  'photo dad hiking special need son touch heart',
#  '56 year veteran win va',
#  'soak sun may tanning addict',
#  'selfiediagnosis stroke selfie lead treatment',
#  'mystery birth defect cluster diet blame',
#  'dr oz effect hooked american consumer',
#  'smartphone selfie video lead stroke diagnosis',
#  'black box warning antidepressant raised suicide attempt',
#  'cuba confirms first six case chikungunya',
#  'silver obamacare lining 69 monthly premium',
#  'keep bun oven induced birth decline',
#  'cricket food future',
#  'fda urge restaurant consumer cut salt',
#  'u get new flu vaccine',
#  'new meningitis b vaccine sent fda review',
#  'thirty member congress support eased medical marijuana research',
#  'dr oz effect senator scold mehmet oz diet scam',
#  'happen preemie twin born 39 day apart',
#  'looking cure u try save aid baby',
#  'looking cure u try cure aid baby',
#  'fda prepping longawaited plan reduce salt',
#  'ebola come back vengeance liberia',
#  'mers outbreak could spread annual pilgrimage official',
#  'amid outbreak foster farm step food safety',
#  'here bad sitting around',
#  'working mom may helping kid study find',
#  'doctor become first implant new wireless heart monitor',
#  'human ancestor got herpes chimp',
#  'last u health care rank poorly',
#  'rossen report doctor stoned',
#  'whooping cough officially epidemic california',
#  'bionic pancreas astonishes diabetes researcher',
#  'kid caffeine dangerous combination',
#  'father know best dad share creative parenting hack',
#  'mexico win mean sex thing work',
#  'wait doctor vary widely outside va',
#  'startup launch first wearable health record google glass',
#  'shire test adhd drug 4 5yearolds',
#  'happy today carrying alzheimers strike early',
#  'cdc fewer teen smoke text driving',
#  'braincontrolled iron man suit kick world cup',
#  'bad news bbq hot dog may raise heart disease risk',
#  'genetically there thing mexican',
#  'standing get employee pumped meeting study',
#  'cancer cost later 4000 year',
#  'teen smoking sex hit new low texting fat new danger',
#  'twin born 24 day apart headed home rare delivery',
#  'summer bummer school kid put pound',
#  'diaper duty dad fight right potty parity',
#  'revenge nerd cool kid may unhappy adult',
#  'metal dad behind viral photo explains parenthood rock',
#  'red meat linked breast cancer risk',
#  'scientist make mutant infectious flu virus lab',
#  'cant handle truth kid know dont get full story',
#  'dr sunscreen drinking cup bust',
#  'fat american dont think poll find',
#  'bye barefoot runner fatsoled shoe may protect aging joint',
#  'men shack dont get healthpromoting benefit',
#  'prediabetic growing epidemic alarm doctor',
#  'red meat possibly linked breast cancer study suggests',
#  'rt come back increasing number american living diabetes million dont even know',
#  'mole check surprising new sign breast cancer risk',
#  'cause nasty garlic breath science answer',
#  'pregnant woman eat fish fda say',
#  'let go grabbed brain still wont let go',
#  'eye dish researcher make retina stem cell',
#  'alarming rise 29 million american diabetes',
#  'boy experiment could end biting mosquito',
#  'want better deal car put angry face',
#  'redefining dad mean man today',
#  'seattle doc suspended sexting surgery',
#  'breastfeeding backlash mom graduation photo stir controversy',
#  'early xrays barely raise cancer risk study find',
#  'white house conference country care working dad',
#  'angel face retreat healing journey burned teen girl',
#  'hidden danger undeclared allergen lurk many food',
#  'new sids registry track clue infant death',
#  'alexs lemonade stand surpasses goal 79 million',
#  'rare ohio mono mono twin home father day',
#  'two year miracle birth mom continues recovery',
#  'growing ebola outbreak threatens overwhelm volunteer',
#  'pulling iffy birth control plan still popular',
#  'white house climate change ruining health',
#  'slender man seductive power kid brain',
#  'costco warns member salmonella pepper',
#  'dirty baby healthy baby early filth may reduce allergy',
#  'stem cell treat multiple sclerosis mouse',
#  'employer may eyeing new obamacare exchange',
#  'white house enlists sport star obamacare push',
#  'obamacare foe newly insured put donut',
#  'kid original drawing become cherished plush toy',
#  'yes nasty flu year cdc confirms',
#  'chikungunya case double caribbean',
#  'kid know slender man',
#  'health insurance premium growing since 2008',
#  '13dayold baby becomes youngest fitted artificial heart',
#  'kid know slender man',
#  'ebola case spike guinea sierra leone',
#  'health food sprouted chia seed powder sickens 17',
#  'boy mysterious infection cured dna sequencing',
#  'maureen dowds bad pot trip reminder easy eat much',
#  'new report nail camel direct source mers',
#  'huggies heist diaper bank robber lift 13k load',
#  'two million obamacare discrepancy',
#  'food isnt enough gut bug affect malnutrition study find',
#  'heart attack rescue there app',
#  'godfather ecstasy alexander shulgin dy 88',
#  'dining beware extremely contagious norovirus',
#  'traveler polioridden nation may need booster shot cdc',
#  'bowe bergdahl could face long road reintegration',
#  'innovative new treatment depression offer hope patient',
#  'norovirus think restaurant cruise ship cdc say',
#  'former bully 7 campaign bullying',
#  'saudi official find extra mers case',
#  'chicago slap painkiller maker lawsuit risk',
#  'breastfeeding selfies portrait let new mom flaunt nursing pride',
#  'dad grief spur mission kid buckle',
#  'pet jerky treat deal six thing need know',
#  'breast milk health food men expert say',
#  'toddler nearfatal secondary drowning warning parent',
#  'one rare cancer lead another cancer registry save baby life',
#  'fighting back patient immune cell tackle cervical cancer',
#  'boston bomb attack triggered ptsd local kid study find',
#  'new joe camel ecigarette ad spook antismoking activist',
#  'rare mono mono twin could home within week',
#  'scientist discover blonde gene',
#  'breast cancer gene also cause lung cancer',
#  'chemo equal longer life prostate cancer patient',
#  'drug may help breast cancer patient get pregnant',
#  'new pill help leukemia patient live longer',
#  'jerky pet treat deal maker agree 65 million fund',
#  'drug protects ovary chemo study demonstrates',
#  'popular best day start diet',
#  'va shakeup brings veteran mix relief worry',
#  'fertility pause help woman baby chemo',
#  'ovary freeze help woman baby chemo',
#  'bright idea scientist use laser light regrow teeth',
#  'fertility freeze help woman baby chemo',
#  'medicare lift transgender surgery coverage ban',
#  'solvent may raise breast cancer risk study find',
#  'fda announces stricter tanning bed rule',
#  'richard iii really twisted new analysis show',
#  'fed put new age restriction tanning bed',
#  'president obama ive probably mild concussion',
#  'obama sure suffered concussion playing football',
#  'measles case u spike highest level 20 year',
#  'oklahoman push allow medical marijuana',
#  'concussion crisis white house summit tackle brain injury',
#  'say bring spouse noisy party',
#  'college student slut shame class thing',
#  'white house plan tackle youth sport concussion',
#  'whole world getting fatter new survey find',
#  'tainted meat group sue usda salmonella',
#  'could cynical cause dementia',
#  'new face heroin young white suburban study find',
#  'peer pressure last three day study say',
#  'doctor new weight loss surgery winner',
#  'cdc backtracks illinois man didnt mers',
#  'help troubled child late',
#  'dad chore may bolster daughter career dream',
#  'food fight michelle obama guard let move campaign',
#  'florida woman 46 set record birth via ivf',
#  'first lady responds school meal critic congress',
#  'college student sickened big beef recall lawsuit',
#  'survivor chic mastectomy swimwear hit market',
#  'salmonella surprise 574 sick foster farm outbreak cdc say',
#  'brain implant allows baby girl born deaf hear',
#  'economic slowdown could linked rise obesity rate',
#  'empathy workout brain training may boost altruism',
#  'say woman expecting',
#  'grandma baby shower celebrate fun stage life',
#  'happy dance texas girl track obesity surgery doc say',
#  'wild health insurance rate hike may settle filing show',
#  'five dead sierra leone first ebola outbreak',
#  'worried mers there came',
#  'pregnant woman need iodine supplement doctor say',
#  'house divided vaccine cause family conflict',
#  'va let vet get private care',
#  'va let vet get private care',
#  'portland ore resident drink tap water without boil',
#  'portland ore resident drink tap water without first boiling',
#  'portland ore resident longer boil tap water',
#  'climate blue environmentalist chill warming world',
#  'british doctor livestreams cancer surgery using google glass',
#  'e coli found portland water supply',
#  'e coli contaminates portland ore tap water',
#  'iv shortage hit rural clinic hard',
#  'flat tire get man police ride transplant',
#  '9 simple question may predict heart disease cancer risk',
#  'menu look twice burger hummus memorial day bbq',
#  'memorial day weekend roadrage trigger',
#  'baby spa take stress infant',
#  'dent nfl treated like race horse',
#  'prevent pool electrocution',
#  'e coli beef recall sparked rare bug cdc say',
#  'former nfl lineman kidney got progressively worse every year',
#  'bioethicist nfl team hire doctor',
#  'yelp help pinpoint food poisoning nyc restaurant',
#  'look polio crippling pakistan',
#  'cheap food blamed america obesity crisis',
#  'family loses 222 lb',
#  'gi joe star help dad celebrate son cancer recovery',
#  'future health care america think hispanic',
#  'teen carry brother 40 mile cerebral palsy fight',
#  'petsmart pull chinese jerky pet treat store',
#  'world oldest man 111 reveals key longevity',
#  'woman get double mastectomy dont need study find',
#  'burwell get committee approval hhs job',
#  'subway dress help protect personal space',
#  'back diy dress help protect personal space',
#  'world happiest country would believe paraguay',
#  'petco pull pet treat china dog death',
#  'explayers nfl dispensed drug mask injury',
#  'big ground beef e coli recall expands nationwide',
#  'explayers accuse nfl illegally supplying painkiller',
#  'superhero 5yearold given comicbook funeral',
#  'mers cure lot drug might fight virus study find',
#  'hpv found twothirds american survey find',
#  'petco pull tainted pet jerky treat shelf',
#  'sunscreen spf claim cant trusted report',
#  'handing crack pipe may crackpot scheme',
#  'lifting two pregnant woman max crossfit',
#  'survey find half american cant swim',
#  'hpv found twothirds american survey find',
#  'twothirds u swarming wart virus',
#  'germ plane bacteria linger day study find',
#  'duggars would love kid parent 19 say',
#  'nasal strip ok california chrome work',
#  'terminally ill woman surprised flash mob',
#  'bioethicist right try law cruel compassionate',
#  'florida mers patient go home search others continues',
#  'germ gut may affect autism study find',
#  'thats nut 10000 toddler get drug adhd',
#  'germ gut may affect autism study find',
#  'third mers virus infection confirmed u',
#  'e coli case prompt massive ground beef recall',
#  'third mers virus case confirmed u',
#  'astrazeneca reject 119 billion takeover offer pfizer',
#  'dog sniff prostate cancer',
#  'right try state move expand access experimental drug',
#  'pee sterile study find',
#  'kraft recall 12 million case cottage cheese',
#  'illinois man third u mers infection cdc say',
#  'top official veteran health care leave amid scandal',
#  'rascal flatts raise money patient childrens hospital',
#  'second set mono mono twin born hospital',
#  'rt nicu temporary home another set rare monoamniotic twin',
#  'florida official warn painful new virus',
#  'pet treat mystery dog dead 3 people sick fda say',
#  'fist bump doc handshake ban suggested health care',
#  'vaccine run grieving mom head canada lifesaving shot',
#  'stranger surprise gift help grieving mom cope',
#  'fda lower dosage popular sleeping pill',
#  'black child likely drown pool study show',
#  'minnesota lawmaker reach deal legalizing medical marijuana',
#  'evidence mers spread florida hospital official say',
#  'sleep aid must carry warning drowsiness fda say',
#  'va doc defied opiate rule treating vet audit find',
#  'parent lose kid sport everyone loses',
#  'swimming pool chemical send thousand er cdc say',
#  'here ok start sentence',
#  '22 outrageous baby name 2013',
#  'stephen sutton dy raising million cancer charity',
#  'missouri lawmaker pas 72hour abortion wait period',
#  'second mers case show hospital ground zero mers',
#  'use daily pill prevent hiv infection cdc recommends',
#  'yum 80 meat label could meaningless',
#  'love flash mob help five family battling cancer',
#  'lung cancer screening cost medicare 9 billion study find',
#  'obesity raise breast cancer death rate third',
#  'antidepressant may cut alzheimers protein',
#  'chair charlie cancer patient get help daily dog walk',
#  'two health worker feared infected mers test negative',
#  'new glass measure fatigue',
#  'mom delivering handholding twin overwhelming',
#  'mers global emergency yet say',
#  'dr nancy need know mers',
#  'dr nancy need know mers virus',
#  'mysterious birth defect answer question expert say',
#  'walmart settle colorado listeria outbreak victim',
#  'tsa warns traveler deadly mers virus',
#  'video tsa warns traveler deadly mers virus via',
#  'casey kasems littleknown dementia heartbreaking doc say',
#  'camel confirmed source mers virus',
#  'handholding twin parent stunned attention',
#  'er visit concussion spike damage becomes clear',
#  '3 easy exercise squeeze busiest day',
#  'florida hospital worker treated mers patient also ill',
#  'mers search disease detective beat bush virus',
#  'first u mers patient leaf hospital',
#  'second mers case confirmed',
#  'mers u youll see',
#  'second u mers case found florida',
#  '4 habit mess metabolism',
#  'florida hospital worker treated mers patient also ill',
#  'white house watching possible mers case closely',
#  'florida hospital worker treated mers patient fall ill',
#  'hospital official explain fast mers virus spread',
#  'two hospital worker treated mers patient ill',
#  'rare birth photo go viral',
#  'second mers case confirmed',
#  'parent battle hiv discrimination child',
#  'mers search disease detective beat bush virus',
#  'mers mystery disease detective search infected traveler',
#  'red wine chocolate better health maybe',
#  'ohio measles outbreak biggest u since 1996',
#  'look 60 new computer program give sneak peek',
#  'red wine chocolate better health maybe',
#  'mom open american girl shop help autistic daughter',
#  'mers u youll see',
#  'second u mers case found florida',
#  'second u mers case found florida',
#  'driving pregnant car crash likely study find',
#  'best mother day present rare twin hold hand',
#  'hoda sara bareilles cyndi lauper help kid cancer',
#  'owns health care data',
#  'older woman may face higher risk cervical cancer',
#  'parent smoke kid',
#  'best mother day present rare twin born holding hand',
#  'brain zap could help control dream',
#  'zapping brain may help sleeper control dream',
#  'daughter journey reflection mother day',
#  'motherhood number job changed',
#  'first u mers patient leaf hospital',
#  'veteran family pour frustration va hospital scandal',
#  'fda approves star war robotic arm amputee',
#  'kissing easter chick lead salmonella outbreak',
#  'arianna huffington exhaustion collapse wakeup call',
#  'mailorder chick infect 63 people cdc say',
#  'woman whose real bikini pic went viral get magazine shoot',
#  'woman whose weightloss bikini pic went viral get shape magazine shoot',
#  'emily letts youtube abortion foe wont respond hate',
#  'pregnant opiate following doctor order break law',
#  'dont call grandma birth older mom rise',
#  ...]

# %%
cleaned[1]
# Out:
# 'pregnant woman taken life support ireland'

# %%
stem(remPunct(remUserLinkCase(twitter["content"])), remStop = True)

# %%
stem(remPunct(remUserLinkCase(twitter["content"])), remStop = False)

# %%
lem(remPunct(remUserLinkCase(twitter["content"])), remStop = True)

# %%
lem(remPunct(remUserLinkCase(twitter["content"])), remStop = False)
